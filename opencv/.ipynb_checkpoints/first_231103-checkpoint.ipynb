# %% [markdown]
# ## 伟大的章鱼哲学

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# **加粗（注意：没有空格）**
# # 这是一级标题（注意有空格）
# ###### 这是六级标题（注意有空格）
#
# [b站](https://www.bilibili.com/)
#
# # 上面是插入网址   []-链接名称自己起，（）-链接
# ![anime-koshechek-12.jpg](attachment:anime-koshechek-12.jpg)
#
# # 上面是插入图片，直接拖拽进这里就行，，，可是我老是成功不了！！！

# %% [markdown]
# ## ctrl+enter 选中当前单元格
# ## shift+enter 运行单元格，并选择下面的单元格
# ## alt+enter 运行单元格，并在下面插入一个新的单元格
#
#
# # 快捷键
# ## A在上面插入单元格，B在下面插入单元格
# ## M makedown Y代码
# ## 按两下D 删除选中的单元格
# ## H 所有的快捷键
#
# ## X 删除单元格
# ## Y撤销
#
# # esc 命令模式
# # enter 编辑模式（即可修改）
#
# # c 复制 v 粘贴单元格 shift+v 粘贴代码
#
# # L显示代码行数

# %%
cat = ['s',1,2,3,4,5]
cat_copy = []
for tmp in cat:
    cat_copy.append()=tmp
print(cat_copy)
# Out:
#   Cell In[13], line 4
#     cat_copy.append()=tmp
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %% [markdown]
# # 插入数学公式 用两个美元符号夹住
#
# ## 质能方程 $E=mc^2$
